# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajesh gupta\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv('Housing.csv')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
d.head(7)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
# 5  10850000  7500         3          3        1      yes        no      yes
# 6  10150000  8580         4          3        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# 5              no             yes        2      yes   semi-furnished
# 6              no             yes        2      yes   semi-furnished

# %% [markdown]
# # converting into numeric data

# %%
map={'yes':1,'no':0}

# %%
d.mainroad=d.mainroad.map(map)
d.guestroom=d.guestroom.map(map)
d.basement=d.basement.map(map)
d.prefarea=d.prefarea.map(map)
d.airconditioning=d.airconditioning.map(map)
d.hotwaterheating=d.hotwaterheating.map(map)

# %%
d.furnishingstatus.value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
map2={'semi-furnished':1,'unfurnished':0,"furnished":2}

# %%
d.furnishingstatus=d.furnishingstatus.map(map2)

# %% [markdown]
# # Corelation

# %%
cor=d.corr()

# %%
plt.figure(figsize=(12,7))
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(d)

# %% [markdown]
# # Training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
d_train,d_test=train_test_split(d,random_state=22,test_size=0.2)

# %% [markdown]
# # Training LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
train_input=d_train[['area','bathrooms','bedrooms','stories','basement','mainroad','guestroom','airconditioning','parking','prefarea','furnishingstatus']]
train_target=d_train['price']
model.fit(train_input,train_target)
# Out:
# LinearRegression()

# %%
test_input=d_test[['area','bathrooms','bedrooms','stories','basement','mainroad','guestroom','airconditioning','parking','prefarea','furnishingstatus']]
test_output=d_test['price']

# %%
prediction=model.predict(test_input)

# %%
prediction
# Out:
# array([5597177.91424847, 4048587.4993392 , 2151386.85767858,
#        6001100.99499539, 3933164.22140367, 7437326.73572842,
#        6263970.32236729, 7433753.79539892, 5038676.49134753,
#        5199055.0503697 , 7421233.09035655, 5231376.35514289,
#        4560774.06789482, 5185884.15678347, 4748167.47249228,
#        5759664.10838218, 3536310.92117992, 7782440.7210749 ,
#        3579792.17069311, 3284359.98118348, 3111993.92946936,
#        4074575.40642738, 5182107.72748316, 4682389.26021874,
#        3555231.64163232, 3832676.18643447, 7525916.78563207,
#        3227545.39947408, 4145440.87071129, 6014626.46034617,
#        3008949.34919085, 3586394.61231845, 3690698.95780764,
#        3335216.82100337, 2849457.0787626 , 3157780.22623734,
#        4488771.28253034, 6950977.9400578 , 3272852.05278532,
#        3608077.92512343, 5075915.78809608, 2717965.16666037,
#        3452379.0041322 , 4762605.74768809, 5171079.72646642,
#        5381955.49349173, 2677963.1856754 , 6084246.41156759,
#        4040997.0261656 , 3103049.85240085, 5833984.70122706,
#        5217675.7578265 , 3263255.15413979, 5169244.92479316,
#        3439103.09342913, 4316580.80034006, 6394460.20650976,
#        3388556.5325743 , 5524125.12191731, 3670347.11673521,
#        3454302.88187266, 5061223.67056211, 5204371.06437948,
#        2752358.27237109, 4069617.74258092, 4124354.42155247,
#        4046797.33005106, 3435266.21611505, 3102502.79920574,
#        3129010.27215144, 4824199.35874078, 7759105.87743743,
#        3702121.98456209, 5328029.14125611, 3334002.66134409,
#        5482860.29220847, 2997420.64593833, 5793632.71842622,
#        6427907.60498133, 5907482.5259265 , 2771974.38166493,
#        7898680.92793874, 4398089.48110131, 4014432.47578575,
#        6345625.54698474, 4784027.81409398, 3323101.32973232,
#        4710551.56354867, 4219259.82710026, 8337096.02891944,
#        3238363.44963128, 2341192.57906857, 5928417.10517955,
#        6528189.73651129, 7461944.46123746, 6142157.34783187,
#        4417497.70109021, 6139979.75557554, 2403407.40971052,
#        4816345.63596727, 3120284.39075099, 5735788.40498802,
#        5138867.24240891, 4626068.7373611 , 5998712.35001043,
#        3642805.8937519 , 4741344.55385294, 5374059.35036874,
#        5717376.84829754])

# %% [markdown]
# # Evaluating Model

# %%
from sklearn.metrics import root_mean_squared_error

# %%
def rmse(x,y):
    return root_mean_squared_error(x,y)

# %%
loss=rmse(test_output,prediction)
print('loss:',loss)
# Out:
# loss: 1141245.126650685

# %%
test_output
# Out:
# 178    5229000
# 228    4690000
# 501    2660000
# 22     8645000
# 204    4900000
#         ...
# 122    5950000
# 262    4445000
# 268    4382000
# 67     6895000
# 120    5950000
# Name: price, Length: 109, dtype: int64

# %%
d_test
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 178  5229000  7085         3          1        1         1          1
# 228  4690000  3630         3          1        2         1          0
# 501  2660000  2430         3          1        1         0          0
# 22   8645000  8050         3          1        1         1          1
# 204  4900000  4770         3          1        1         1          1
# ..       ...   ...       ...        ...      ...       ...        ...
# 122  5950000  6254         4          2        1         1          0
# 262  4445000  3750         2          1        1         1          1
# 268  4382000  4950         4          1        2         1          0
# 67   6895000  7700         3          2        1         1          0
# 120  5950000  6540         3          1        1         1          1
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 178         1                0                0        2         1
# 228         0                0                0        2         0
# 501         0                0                0        0         0
# 22          1                0                1        1         0
# 204         1                0                0        0         0
# ..        ...              ...              ...      ...       ...
# 122         1                0                0        1         1
# 262         1                0                0        0         0
# 268         0                0                1        0         0
# 67          0                0                0        2         0
# 120         1                0                0        2         1
#
#      furnishingstatus
# 178                 1
# 228                 1
# 501                 0
# 22                  2
# 204                 1
# ..                ...
# 122                 1
# 262                 1
# 268                 1
# 67                  0
# 120                 2
#
# [109 rows x 13 columns]

# %%
sns.scatterplot(y=test_output,x=prediction)
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# ### This graph shows that model has made poor predictions since the gaph is not a straight line.

# %%
sns.distplot(test_output)
# Out:
# C:\Users\Rajesh Gupta\AppData\Local\Temp\ipykernel_11540\3822336011.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(test_output)
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(x=prediction)
plt.show()
# Out:
# C:\Users\Rajesh Gupta\AppData\Local\Temp\ipykernel_11540\1367089904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=prediction)

# %% [markdown]
# ### There is a significant difference between the actual price graph and the model predicted price graph.
